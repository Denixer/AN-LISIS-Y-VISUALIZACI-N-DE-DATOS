# %% [markdown]
# <a href="https://colab.research.google.com/github/Denixer/AN-LISIS-Y-VISUALIZACI-N-DE-DATOS/blob/main/consultas_medicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cargar librerias
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# Cargar base de dato
from google.colab import files

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel ("/content/drive/MyDrive/CONSULTAS_MEDICAS_2019_2023.xlsx")

# %%
# comando para mostar los campos con su wwww de una tabla
df.dtypes
# Out:
# AÑO                          int64
# MES                         object
# ESPECIALIDAD                object
# TOTAL                        int64
# 0_4                        float64
# 5_9                        float64
# 10 _14                     float64
# 15_19                      float64
# 20_24                      float64
# 25_29                      float64
# 30_34                      float64
# 35_39                      float64
# 40_44                      float64
# 45_49                      float64
# 50_54                      float64
# 55_59                      float64
# 60_64                      float64
# 65_69                      float64
# 70 _74                     float64
# 75_79                      float64
# 80_mas                     float64
# BENEFICIARIOS                int64
# Hombres                    float64
# Mujeres                    float64
# TOTAL_MEN                    int64
# NUEVA_APS_MEN15            float64
# NUEVA_CAE_MEN15            float64
# NUEVA_URG_MEN15            float64
# TOTAL_MAY                    int64
# NUEVA_APS_15MAS            float64
# NUEVA_CAE_15MAS            float64
# NUEVA_URG_15MAS            float64
# NSP_NUEVAS                 float64
# NSP_CONTROLES              float64
# CONSULTA_ABREVIADA         float64
# ALTAS_MENOS_15\n15 años    float64
# ALTAS_MAS_15               float64
# Compras_Servicio           float64
# operativos                 float64
# GENERAL_MENOS_15           float64
# GENERAL_MAS15              float64
# TOTAL_NUEVAS                 int64
# TOTAL_NSP                    int64
# TOTAL_ALTAS                  int64
# dtype: object

# %%
df.head(5)
# Out:
#     AÑO    MES                                       ESPECIALIDAD  \
# 0  2019  ENERO                                          PEDIATRÍA
# 1  2019  ENERO                                   MEDICINA INTERNA
# 2  2019  ENERO                                       NEONATOLOGÍA
# 3  2019  ENERO  ENFERMEDAD RESPIRATORIA PEDIÁTRICA (BRONCOPULM...
# 4  2019  ENERO  ENFERMEDAD RESPIRATORIA DE ADULTO (BRONCOPULMO...
#
#    TOTAL                   0_4   5_9  10 _14  15_19  20_24  25_29  ...  \
# 0                   180  106.0  46.0    19.0    8.0    0.0    0.0  ...
# 1                   473    0.0   0.0     0.0    4.0   12.0   12.0  ...
# 2                   104  104.0   NaN     NaN    NaN    NaN    NaN  ...
# 3                   120   43.0  34.0    35.0    8.0    0.0    0.0  ...
# 4                   117    0.0   0.0     0.0    1.0    1.0    3.0  ...
#
#    CONSULTA_ABREVIADA  ALTAS_MENOS_15\n15 años  ALTAS_MAS_15  \
# 0                 NaN                      NaN           NaN
# 1                24.0                      NaN           NaN
# 2                 NaN                      NaN           NaN
# 3                 NaN                      NaN           NaN
# 4                 NaN                      NaN           NaN
#
#    Compras_Servicio  operativos  GENERAL_MENOS_15  GENERAL_MAS15  \
# 0               NaN         NaN               NaN            NaN
# 1               NaN         NaN               NaN            NaN
# 2               NaN         NaN               NaN            NaN
# 3               NaN         NaN               NaN            NaN
# 4               NaN         NaN               NaN            NaN
#
#    TOTAL_NUEVAS  TOTAL_NSP  TOTAL_ALTAS
# 0            40          0           10
# 1           129          0            0
# 2            27          0            0
# 3            13          0            3
# 4            24          0            0
#
# [5 rows x 44 columns]
