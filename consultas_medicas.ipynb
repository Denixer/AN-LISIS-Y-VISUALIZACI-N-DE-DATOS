# %% [markdown]
# <a href="https://colab.research.google.com/github/Denixer/AN-LISIS-Y-VISUALIZACI-N-DE-DATOS/blob/main/consultas_medicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cargar librerias
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# Cargar base de dato
from google.colab import files

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel ("/content/drive/MyDrive/CONSULTAS_MEDICAS_2019_2023.xlsx")

# %%
# comando para mostar los campos con su wwww de una tabla
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5aaed6bf18fc> in <cell line: 2>()
#       1 # comando para mostar los campos con su wwww de una tabla
# ----> 2 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df.head(5)
# Out:
#     AÑO    MES                                       ESPECIALIDAD  \
# 0  2022  ENERO                                          PEDIATRÍA
# 1  2022  ENERO                                   MEDICINA INTERNA
# 2  2022  ENERO                                       NEONATOLOGÍA
# 3  2022  ENERO  ENFERMEDAD RESPIRATORIA PEDIÁTRICA (BRONCOPULM...
# 4  2022  ENERO  ENFERMEDAD RESPIRATORIA DE ADULTO (BRONCOPULMO...
#
#    TOTAL                  0_4   5_9  10 _14  15_19  20_24  25_29  ...  \
# 0                   100  42.0  25.0    28.0    5.0    0.0    0.0  ...
# 1                    42   0.0   0.0     0.0    1.0    1.0    1.0  ...
# 2                    59  59.0   NaN     NaN    NaN    NaN    NaN  ...
# 3                    96  41.0  23.0    27.0    5.0    0.0    0.0  ...
# 4                   112   0.0   0.0     2.0    5.0    2.0    1.0  ...
#
#    operativos  GENERAL_MENOS_15  GENERAL_MAS15  CONTRA_MENOS15  CONTRA_MAS15  \
# ...
